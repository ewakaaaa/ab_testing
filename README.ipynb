# %%
from User import User 
from Plotter import Plotter
from Simulation import Simulation
from Bayesian import Bayesian
from MultiArmBandit import MultiArmBandit

# %% [markdown]
# ### Introduction
# A / B testing is a very popular optimization method. They are aimed at improving a given measure through continuous learning and testing hypotheses. They gained popularity because the results are very easy to interpret.Our problem is which version A or B is better?
#
# ### Assumptions
# - user behavior on each variance (A and B) is simulated by beta distribution with parameters $\alpha$ and $\beta$,
# - a priori of Bayesian induction is uniform distribution, $\mathcal{U}(0,1)$,

# %%
user_a = User(0.1,2000)
user_b = User(0.2,2000)

user_a.generate_user_clicks()
user_b.generate_user_clicks()

# %% [markdown]
# If you want to plot your results init plotter

# %%
plotter = Plotter()

# %% [markdown]
# ### Frequency approach
# Math and code: https://towardsdatascience.com/the-math-behind-a-b-testing-with-example-code-part-1-of-2-7be752e1d06f
#
# ### Bayesian inference
# Math: https://cdn2.hubspot.net/hubfs/310840/VWO_SmartStats_technical_whitepaper.pdf

# %%
bayesian = Bayesian(user_a, user_b, 0.0001, plotter)
bayesian.simulate(1)

# %%
print(bayesian.get_winner_arm())
print(bayesian.observations_performed())
# Out:
# b
# 316

# %%
bayesian.plot_probabilities()

# %%
bayesian.plot_loss()

# %% [markdown]
# ### Multi-armed bandits algorithm
# Math: http://proceedings.mlr.press/v23/agrawal12/agrawal12.pdf

# %%
multiarmbandit = MultiArmBandit(user_a, user_b, 0.8, plotter) 
multiarmbandit.simulate(0.1)

# %%
print(multiarmbandit.get_winner_arm())
print(multiarmbandit.observations_performed())
# Out:
# b
# 101

# %%
multiarmbandit.plot_probabilities()

# %%
multiarmbandit.plot_winning_arm()
